# %% [markdown]
# # Preparación de las series de datos para el nuevo artículo

# %%
from ipywidgets import IntProgress
from IPython.display import display
import time

from covid19_vulnerabilidad_mex.datos import *
from covid19_vulnerabilidad_mex.vulnerabilidad import *

import pandas as pd
import geopandas as gpd

import glob
import os
import matplotlib.pyplot as plt
import numpy as np

from datetime import timedelta
import datetime
from datetime import timedelta, date, datetime
import pickle

from sklearn.feature_selection import SelectKBest, chi2
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.cross_decomposition import PLSRegression

import seaborn as sns
import imageio
from pygifsicle import optimize

plt.style.use('ggplot')

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Nuevos datos base
#
# A partir de los datos preparados en `08_Actualizacion_Datos` vamos a preparar dos dataframes, uno con la selección de variables básica derivada de Acharya y otro con una selección extendida.
#
# El diccionario `datos/municipios/actualizacion_2020/diccionario_dysovi.csv` nos dice qué variables se usan en cada selección a través de las columnas `Base Index` y `Extended`, mientras que la columna `datos` contiene el nombre de la columna en la base actualizada

# %%
diccionario = pd.read_csv("datos/municipios/actualizacion_2020/diccionario_dysovi.csv")
# Estas columnas tienen información de identificación que no vamos a usar en los modelos
id_vars = ["entidad_cvegeo", "State", "municipio_cvegeo", "Municipality"]
diccionario.head()
# Out:
#    id             datos Base Index Extended
# 0   0    entidad_cvegeo        NaN      NaN
# 1   1             State        NaN      NaN
# 2   2  municipio_cvegeo        NaN      NaN
# 3   3      Municipality        NaN      NaN
# 4   4        Population        NaN      NaN

# %% [markdown]
# Obtenemos las variables de los índices base y extendido

# %%
# Las columnas
base_index_vars = diccionario.loc[diccionario['Base Index'].notnull()]['datos'].values
extended_index_vars = diccionario.loc[diccionario['Extended'].notnull()]['datos'].values
# Leemos datos
indicadores_municipales = pd.read_csv("datos/municipios/actualizacion_2020/indicadores_finales.csv", dtype={'entidad_cvegeo':str, 'municipio_cvegeo':str})
indicadores_base = indicadores_municipales.loc[:, id_vars + list(base_index_vars) + ['Population']]
indicadores_extended = indicadores_municipales.loc[:,id_vars + list(extended_index_vars) + ['Population']]
indicadores_extended
# Out:
#      entidad_cvegeo           State municipio_cvegeo           Municipality  \
# 0                01  Aguascalientes            01001         Aguascalientes
# 1                01  Aguascalientes            01002               Asientos
# 2                01  Aguascalientes            01003               Calvillo
# 3                01  Aguascalientes            01004                  Cosío
# 4                01  Aguascalientes            01005            Jesús María
# ...             ...             ...              ...                    ...
# 1645             32       Zacatecas            32053  Villa González Ortega
# 1646             32       Zacatecas            32054          Villa Hidalgo
# 1647             32       Zacatecas            32055             Villanueva
# 1648             32       Zacatecas            32056              Zacatecas
# 1649             32       Zacatecas            32057               Trancoso
#
#           Male    Female  60 and older  60 and older males  \
# 0     0.486910  0.513090      0.108523            0.048750
# 1     0.490162  0.509838      0.091140            0.044260
# 2     0.490352  0.509648      0.134403            0.064961
# 3     0.487765  0.512235      0.094882            0.045706
# 4     0.494262  0.505738      0.075541            0.036274
# ...        ...       ...           ...                 ...
# 1645  0.475091  0.524909      0.123107            0.059737
# 1646  0.488738  0.511262      0.109328            0.054510
# 1647  0.494011  0.505989      0.178655            0.086729
# 1648  0.481074  0.518926      0.125977            0.056261
# 1649  0.490785  0.509215      0.087265            0.042728
#
#       60 and older females  65 and older  ...  \
# 0                 0.059773      0.071593  ...
# 1                 0.046880      0.064634  ...
# 2                 0.069442      0.096841  ...
# 3                 0.049176      0.065765  ...
# 4                 0.039268      0.050320  ...
# ...                    ...           ...  ...
# 1645              0.063371      0.088431  ...
# 1646              0.054818      0.077754  ...
# 1647              0.091926      0.135655  ...
# 1648              0.069716      0.082677  ...
# 1649              0.044537      0.058519  ...
#
#       People under minnimum wellness line  \
# 0                                    10.0
# 1                                    24.4
# 2                                    26.8
# 3                                    16.6
# 4                                     7.9
# ...                                   ...
# 1645                                 38.8
# 1646                                 38.5
# 1647                                 28.7
# 1648                                  8.5
# 1649                                 30.1
#
#       Beds in public hospitals per (state) habitant  \
# 0                                          0.959461
# 1                                          0.959461
# 2                                          0.959461
# 3                                          0.959461
# 4                                          0.959461
# ...                                             ...
# 1645                                       0.991437
# 1646                                       0.991437
# 1647                                       0.991437
# 1648                                       0.991437
# 1649                                       0.991437
#
#       Beds in private hospitals per (state) habitant  \
# 0                                           0.993091
# 1                                           0.993091
# 2                                           0.993091
# 3                                           0.993091
# 4                                           0.993091
# ...                                              ...
# 1645                                        1.000000
# 1646                                        1.000000
# 1647                                        1.000000
# 1648                                        1.000000
# 1649                                        1.000000
#
#       Number of public hospitals per (state) habitant  \
# 0                                            0.981481
# 1                                            0.981481
# 2                                            0.981481
# 3                                            0.981481
# 4                                            0.981481
# ...                                               ...
# 1645                                         0.824074
# 1646                                         0.824074
# 1647                                         0.824074
# 1648                                         0.824074
# 1649                                         0.824074
#
#       People with hypertension  People with diabetes  People with obesity  \
# 0                    14.942242              7.495861            31.486541
# 1                    15.320425              7.953634            32.282284
# 2                    13.751906              9.172624            40.004293
# 3                    16.431493              7.383116            32.596450
# 4                    12.356755              6.745819            34.731715
# ...                        ...                   ...                  ...
# 1645                 18.491491             10.269404            28.455299
# 1646                 16.920279              9.895491            31.075955
# 1647                 21.746589             12.050064            30.526273
# 1648                 20.010453             11.814172            36.822130
# 1649                 15.941678              8.089966            32.477646
#
#       Population density  Urbanization  Population
# 0               0.000808      0.949900    948990.0
# 1               0.000094      0.344613     51536.0
# 2               0.000063      0.486987     58250.0
# 3               0.000135      0.498647     17000.0
# 4               0.000256      0.750595    129929.0
# ...                  ...           ...         ...
# 1645            0.000031      0.697229     13208.0
# 1646            0.000053      0.249460     19446.0
# 1647            0.000015      0.556151     31558.0
# 1648            0.000339      0.943786    149607.0
# 1649            0.000097      0.832119     20455.0
#
# [1650 rows x 40 columns]

# %%
indicadores_base
# Out:
#      entidad_cvegeo           State municipio_cvegeo           Municipality  \
# 0                01  Aguascalientes            01001         Aguascalientes
# 1                01  Aguascalientes            01002               Asientos
# 2                01  Aguascalientes            01003               Calvillo
# 3                01  Aguascalientes            01004                  Cosío
# 4                01  Aguascalientes            01005            Jesús María
# ...             ...             ...              ...                    ...
# 1645             32       Zacatecas            32053  Villa González Ortega
# 1646             32       Zacatecas            32054          Villa Hidalgo
# 1647             32       Zacatecas            32055             Villanueva
# 1648             32       Zacatecas            32056              Zacatecas
# 1649             32       Zacatecas            32057               Trancoso
#
#       60 and older  Disabled  Dwellers per room  Índice de rezago social  \
# 0         0.108523  0.050080               0.84                -1.315320
# 1         0.091140  0.056000               1.07                -0.857301
# 2         0.134403  0.070180               0.97                -0.918554
# 3         0.094882  0.047353               1.14                -1.004023
# 4         0.075541  0.038760               0.95                -1.173361
# ...            ...       ...                ...                      ...
# 1645      0.123107  0.069428               0.96                -0.787429
# 1646      0.109328  0.072200               1.08                -0.692240
# 1647      0.178655  0.067463               0.84                -0.884952
# 1648      0.125977  0.056515               0.75                -1.336926
# 1649      0.087265  0.049866               1.13                -0.748505
#
#       Poverty  Educational lag  ...  Basic services lag  \
# 0        26.1             11.7  ...                 3.0
# 1        54.0             19.8  ...                16.2
# 2        56.8             23.2  ...                 7.7
# 3        43.2             14.7  ...                 7.6
# 4        25.0             17.3  ...                 6.3
# ...       ...              ...  ...                 ...
# 1645     69.1             23.6  ...                14.7
# 1646     71.8             20.8  ...                20.2
# 1647     61.0             26.1  ...                16.0
# 1648     25.9             10.4  ...                 4.6
# 1649     63.1             19.5  ...                13.7
#
#       Beds in public hospitals per (state) habitant  \
# 0                                          0.959461
# 1                                          0.959461
# 2                                          0.959461
# 3                                          0.959461
# 4                                          0.959461
# ...                                             ...
# 1645                                       0.991437
# 1646                                       0.991437
# 1647                                       0.991437
# 1648                                       0.991437
# 1649                                       0.991437
#
#       Beds in private hospitals per (state) habitant  \
# 0                                           0.993091
# 1                                           0.993091
# 2                                           0.993091
# 3                                           0.993091
# 4                                           0.993091
# ...                                              ...
# 1645                                        1.000000
# 1646                                        1.000000
# 1647                                        1.000000
# 1648                                        1.000000
# 1649                                        1.000000
#
#       Number of public hospitals per (state) habitant  \
# 0                                            0.981481
# 1                                            0.981481
# 2                                            0.981481
# 3                                            0.981481
# 4                                            0.981481
# ...                                               ...
# 1645                                         0.824074
# 1646                                         0.824074
# 1647                                         0.824074
# 1648                                         0.824074
# 1649                                         0.824074
#
#       People with hypertension  People with diabetes  People with obesity  \
# 0                    14.942242              7.495861            31.486541
# 1                    15.320425              7.953634            32.282284
# 2                    13.751906              9.172624            40.004293
# 3                    16.431493              7.383116            32.596450
# 4                    12.356755              6.745819            34.731715
# ...                        ...                   ...                  ...
# 1645                 18.491491             10.269404            28.455299
# 1646                 16.920279              9.895491            31.075955
# 1647                 21.746589             12.050064            30.526273
# 1648                 20.010453             11.814172            36.822130
# 1649                 15.941678              8.089966            32.477646
#
#       Population density  Urbanization  Population
# 0               0.000808      0.949900    948990.0
# 1               0.000094      0.344613     51536.0
# 2               0.000063      0.486987     58250.0
# 3               0.000135      0.498647     17000.0
# 4               0.000256      0.750595    129929.0
# ...                  ...           ...         ...
# 1645            0.000031      0.697229     13208.0
# 1646            0.000053      0.249460     19446.0
# 1647            0.000015      0.556151     31558.0
# 1648            0.000339      0.943786    149607.0
# 1649            0.000097      0.832119     20455.0
#
# [1650 rows x 22 columns]

# %% [markdown]
# ## Preparación series de tiempo

# %% [markdown]
# ### Parámetros generales del análisis

# %%
antier = date.today() - timedelta(days=2)
fecha_analisis = antier - timedelta(weeks=2)
fecha_analisis = pd.to_datetime(fecha_analisis)
inicio = pd.to_datetime('20-05-01', yearfirst=True)
fin = antier - timedelta(days=7)
metodo = 'PLS'
ventana_dias = 28
actualizar_datos_salud(fecha_inicio=antier.strftime('%d-%m-%Y')) # Asegurarse de que estan los datos de antier

# %% [markdown]
# ### Serie base

# %%
serie_municipal_base = serie_covid_indicadores_municipales_from_df(indicadores_base,
                                                                       antier.strftime('%y%m%d'),
                                                                       acumulativa=False,
                                                                       dias=ventana_dias,
                                                                       )
serie_municipal_base[['conteo', 'defunciones']] = serie_municipal_base[[f'conteo_{ventana_dias}dias',
                                                              f'defunciones_{ventana_dias}dias']]
serie_municipal_base = serie_municipal_base.drop(columns=[f'conteo_{ventana_dias}dias',
                                   f'defunciones_{ventana_dias}dias'])                                                              
serie_municipal_base = agregar_tasas_municipales(serie_municipal_base, pop_column='Population')
serie_municipal_base.head()
# Out:
# /home/plablo/git/covid19_vulnerabilidad_mex/covid19_vulnerabilidad_mex/datos.py:242: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   df['SEMANA_AÑO_INGRESO'] = df.index.week
# /home/plablo/git/covid19_vulnerabilidad_mex/covid19_vulnerabilidad_mex/datos.py:72: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   return (left.assign(key=1).merge(right.assign(key=1), on='key').drop('key', 1))
#    FECHA_INGRESO     ENTIDAD_RES CLAVE_ENTIDAD_RES   MUNICIPIO_RES  \
# 4     2020-02-27  AGUASCALIENTES                01  AGUASCALIENTES
# 5     2020-02-28  AGUASCALIENTES                01  AGUASCALIENTES
# 12    2020-02-29  AGUASCALIENTES                01  AGUASCALIENTES
# 15    2020-03-01  AGUASCALIENTES                01  AGUASCALIENTES
# 24    2020-03-02  AGUASCALIENTES                01  AGUASCALIENTES
#
#    CLAVE_MUNICIPIO_RES            RESULTADO  conteo  defunciones  \
# 4                01001  Positivo SARS-CoV-2     0.0          0.0
# 5                01001  Positivo SARS-CoV-2     0.0          0.0
# 12               01001  Positivo SARS-CoV-2     0.0          0.0
# 15               01001  Positivo SARS-CoV-2     0.0          0.0
# 24               01001  Positivo SARS-CoV-2     0.0          0.0
#
#                                              geometry  60 and older  ...  \
# 4   POLYGON ((-102.09775 22.02325, -102.11598 22.0...      0.108523  ...
# 5   POLYGON ((-102.09775 22.02325, -102.11598 22.0...      0.108523  ...
# 12  POLYGON ((-102.09775 22.02325, -102.11598 22.0...      0.108523  ...
# 15  POLYGON ((-102.09775 22.02325, -102.11598 22.0...      0.108523  ...
# 24  POLYGON ((-102.09775 22.02325, -102.11598 22.0...      0.108523  ...
#
#     Number of public hospitals per (state) habitant  People with hypertension  \
# 4                                          0.981481                 14.942242
# 5                                          0.981481                 14.942242
# 12                                         0.981481                 14.942242
# 15                                         0.981481                 14.942242
# 24                                         0.981481                 14.942242
#
#     People with diabetes  People with obesity  Population density  \
# 4               7.495861            31.486541            0.000808
# 5               7.495861            31.486541            0.000808
# 12              7.495861            31.486541            0.000808
# 15              7.495861            31.486541            0.000808
# 24              7.495861            31.486541            0.000808
#
#     Urbanization  Population  covid_confirmados_100k  covid_defun_100k  \
# 4         0.9499    948990.0                     0.0               0.0
# 5         0.9499    948990.0                     0.0               0.0
# 12        0.9499    948990.0                     0.0               0.0
# 15        0.9499    948990.0                     0.0               0.0
# 24        0.9499    948990.0                     0.0               0.0
#
#     tasa_covid_letal
# 4                NaN
# 5                NaN
# 12               NaN
# 15               NaN
# 24               NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Serie extendida

# %%
serie_municipal_extended = serie_covid_indicadores_municipales_from_df(indicadores_extended,
                                                                       antier.strftime('%y%m%d'),
                                                                       acumulativa=False,
                                                                       dias=ventana_dias,
                                                                       )
serie_municipal_extended[['conteo', 'defunciones']] = serie_municipal_extended[[f'conteo_{ventana_dias}dias',
                                                              f'defunciones_{ventana_dias}dias']]
serie_municipal_extended = serie_municipal_extended.drop(columns=[f'conteo_{ventana_dias}dias',
                                   f'defunciones_{ventana_dias}dias'])                                                              
serie_municipal_extended = agregar_tasas_municipales(serie_municipal_extended, pop_column='Population')
serie_municipal_extended.head()
# Out:
# /home/plablo/git/covid19_vulnerabilidad_mex/covid19_vulnerabilidad_mex/datos.py:242: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   df['SEMANA_AÑO_INGRESO'] = df.index.week
# /home/plablo/git/covid19_vulnerabilidad_mex/covid19_vulnerabilidad_mex/datos.py:72: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   return (left.assign(key=1).merge(right.assign(key=1), on='key').drop('key', 1))
#    FECHA_INGRESO     ENTIDAD_RES CLAVE_ENTIDAD_RES   MUNICIPIO_RES  \
# 4     2020-02-27  AGUASCALIENTES                01  AGUASCALIENTES
# 5     2020-02-28  AGUASCALIENTES                01  AGUASCALIENTES
# 12    2020-02-29  AGUASCALIENTES                01  AGUASCALIENTES
# 15    2020-03-01  AGUASCALIENTES                01  AGUASCALIENTES
# 24    2020-03-02  AGUASCALIENTES                01  AGUASCALIENTES
#
#    CLAVE_MUNICIPIO_RES            RESULTADO  conteo  defunciones  \
# 4                01001  Positivo SARS-CoV-2     0.0          0.0
# 5                01001  Positivo SARS-CoV-2     0.0          0.0
# 12               01001  Positivo SARS-CoV-2     0.0          0.0
# 15               01001  Positivo SARS-CoV-2     0.0          0.0
# 24               01001  Positivo SARS-CoV-2     0.0          0.0
#
#                                              geometry     Male  ...  \
# 4   POLYGON ((-102.09775 22.02325, -102.11598 22.0...  0.48691  ...
# 5   POLYGON ((-102.09775 22.02325, -102.11598 22.0...  0.48691  ...
# 12  POLYGON ((-102.09775 22.02325, -102.11598 22.0...  0.48691  ...
# 15  POLYGON ((-102.09775 22.02325, -102.11598 22.0...  0.48691  ...
# 24  POLYGON ((-102.09775 22.02325, -102.11598 22.0...  0.48691  ...
#
#     Number of public hospitals per (state) habitant  People with hypertension  \
# 4                                          0.981481                 14.942242
# 5                                          0.981481                 14.942242
# 12                                         0.981481                 14.942242
# 15                                         0.981481                 14.942242
# 24                                         0.981481                 14.942242
#
#     People with diabetes  People with obesity  Population density  \
# 4               7.495861            31.486541            0.000808
# 5               7.495861            31.486541            0.000808
# 12              7.495861            31.486541            0.000808
# 15              7.495861            31.486541            0.000808
# 24              7.495861            31.486541            0.000808
#
#     Urbanization  Population  covid_confirmados_100k  covid_defun_100k  \
# 4         0.9499    948990.0                     0.0               0.0
# 5         0.9499    948990.0                     0.0               0.0
# 12        0.9499    948990.0                     0.0               0.0
# 15        0.9499    948990.0                     0.0               0.0
# 24        0.9499    948990.0                     0.0               0.0
#
#     tasa_covid_letal
# 4                NaN
# 5                NaN
# 12               NaN
# 15               NaN
# 24               NaN
#
# [5 rows x 48 columns]

# %% [markdown]
# Guardamos las dos series como pickles

# %%
serie_municipal_extended.to_pickle("datos/nuevo_articulo/serie_municipal_extended.pkl")
serie_municipal_base.to_pickle("datos/nuevo_articulo/serie_municipal_base.pkl")
